# %% [markdown]
# ## Sumeet Ghodke

# %% [markdown]
# ## Task-3  Image to Pencil Sketch with Python

# %% [markdown]
# ## Data Science Intern

# %%
# %matplotlib inline

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import cv2
from PIL import Image
from IPython.display import display,clear_output

# %% [markdown]
# ## read the image

# %%
image=cv2.imread('Ambani.jpg')  # reading the image

# %%
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=474x316 at 0x17E44FA33D0>

# %% [markdown]
# ## if you wanted to resize the image then

# %%
# img=cv2.resize(img,(200,300))
# display(Image.fromarray(img))

# %% [markdown]
# ## I don't want to resize the image so I will not use it

# %% [markdown]
# ## Converting original to grayscale

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=474x316 at 0x17E42DBEFD0>

# %% [markdown]
# ## Now we need to invert the new gray_scale image

# %%
inverted_image=255-gray_image
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=474x316 at 0x17E44FA3A00>

# %% [markdown]
# ## Now the next step in the process is to blur the image by using the Gaussian Function in OpenCV

# %%
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)

# %% [markdown]
# ## Now invert the blurred image

# %%
invert_blurred=255-blurred
pencil_sketch=cv2.divide(gray_image,invert_blurred,scale=256.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=474x316 at 0x17E44FA3DF0>

# %% [markdown]
# ## And there we come to the end
